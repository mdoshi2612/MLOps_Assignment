# %%
import pandas as pd

# %%
file_path = "Users\Manav Doshi\Documents\LS 2021 Assignments\Fundamentals of MLOps\mlops_assignment\data\creditcard.csv"
df = pd.read_csv(file_path)

# %%
test_dataset = df.sample(frac = 0.1, random_state = 42)
df = df.drop(test_dataset.index)

df.reset_index(drop = True, inplace = True)
test_dataset.reset_index(drop = True, inplace = True)

print('Data for Model Training & Validation: ' + str(df.shape))
print('Unseen Data For Predictions: ' + str(test_dataset.shape))
# Out:
# Data for Model Training & Validation: (256326, 31)
# Unseen Data For Predictions: (28481, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 1   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 2   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 3   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 4   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 1  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 2  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 3 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 4  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
#
#         V26       V27       V28  Amount  Class
# 0  0.125895 -0.008983  0.014724    2.69      0
# 1 -0.139097 -0.055353 -0.059752  378.66      0
# 2 -0.221929  0.062723  0.061458  123.50      0
# 3  0.502292  0.219422  0.215153   69.99      0
# 4  0.105915  0.253844  0.081080    3.67      0
#
# [5 rows x 31 columns]

# %%
from pycaret.classification import *

# %%
expt_basic = setup(
    data = df, 
    target = 'Class', 
    session_id=42,                      # Random seed to ensure reproducibility of the experiment with the same data
    train_size=0.8,                     # 80% training data & 20% held-out validation data
    numeric_imputation="median",        # "mean" by default
    categorical_imputation="mode",      # "constant" (not_available) by default
)
# Out:
# <style  type="text/css" >
# #T_20d7e_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_20d7e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_20d7e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_20d7e_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_20d7e_row0_col1" class="data row0 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_20d7e_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_20d7e_row1_col1" class="data row1 col1" >Class</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_20d7e_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_20d7e_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_20d7e_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_20d7e_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_20d7e_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_20d7e_row4_col1" class="data row4 col1" >(256326, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_20d7e_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_20d7e_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_20d7e_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_20d7e_row6_col1" class="data row6 col1" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_20d7e_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_20d7e_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_20d7e_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_20d7e_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_20d7e_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_20d7e_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_20d7e_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_20d7e_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_20d7e_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_20d7e_row11_col1" class="data row11 col1" >(205060, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_20d7e_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_20d7e_row12_col1" class="data row12 col1" >(51266, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_20d7e_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_20d7e_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_20d7e_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_20d7e_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_20d7e_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_20d7e_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_20d7e_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_20d7e_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_20d7e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_20d7e_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_20d7e_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_20d7e_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_20d7e_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_20d7e_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_20d7e_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_20d7e_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_20d7e_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_20d7e_row21_col1" class="data row21 col1" >d07f</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_20d7e_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_20d7e_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_20d7e_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_20d7e_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_20d7e_level0_row24" class="row_heading level0 row24"

# %%
models()
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# dt             sklearn.tree._classes.DecisionTreeClassifier   True
# svm       sklearn.linear_model._stochastic_gradient.SGDC...   True
# rbfsvm                             sklearn.svm._classes.SVC  False
# gpc       sklearn.gaussian_process._gpc.GaussianProcessC...  False
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# ridge           sklearn.linear_model._ridge.RidgeClassifier   True
# rf          sklearn.ensemble._forest.RandomForestClassifier   True
# qda       sklearn.discriminant_analysis.QuadraticDiscrim...   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostClas...   True
# gbc         sklearn.ensemble._gb.GradientBoostingClassifier   True
# lda       sklearn.discriminant_analysis.LinearDiscrimina...   True
# et            sklearn.ensemble._forest.ExtraTreesClassifier   True
# lightgbm                    lightgbm.sklearn.LGBMClassifier   True

# %%
best_models = compare_models(sort = "F1", fold = 5, n_select = 5)
# Out:
# <style  type="text/css" >
#     #T_c1d05_ th {
#           text-align: left;
#     }#T_c1d05_row0_col0,#T_c1d05_row0_col2,#T_c1d05_row0_col3,#T_c1d05_row0_col4,#T_c1d05_row1_col0,#T_c1d05_row1_col2,#T_c1d05_row1_col3,#T_c1d05_row1_col4,#T_c1d05_row1_col5,#T_c1d05_row1_col6,#T_c1d05_row1_col7,#T_c1d05_row2_col0,#T_c1d05_row2_col1,#T_c1d05_row2_col2,#T_c1d05_row2_col3,#T_c1d05_row2_col4,#T_c1d05_row2_col5,#T_c1d05_row2_col6,#T_c1d05_row2_col7,#T_c1d05_row3_col0,#T_c1d05_row3_col1,#T_c1d05_row3_col2,#T_c1d05_row3_col3,#T_c1d05_row3_col4,#T_c1d05_row3_col5,#T_c1d05_row3_col6,#T_c1d05_row3_col7,#T_c1d05_row4_col0,#T_c1d05_row4_col1,#T_c1d05_row4_col2,#T_c1d05_row4_col3,#T_c1d05_row4_col4,#T_c1d05_row4_col5,#T_c1d05_row4_col6,#T_c1d05_row4_col7,#T_c1d05_row5_col0,#T_c1d05_row5_col1,#T_c1d05_row5_col3,#T_c1d05_row5_col4,#T_c1d05_row5_col5,#T_c1d05_row5_col6,#T_c1d05_row5_col7,#T_c1d05_row6_col0,#T_c1d05_row6_col1,#T_c1d05_row6_col2,#T_c1d05_row6_col3,#T_c1d05_row6_col4,#T_c1d05_row6_col5,#T_c1d05_row6_col6,#T_c1d05_row6_col7,#T_c1d05_row7_col0,#T_c1d05_row7_col1,#T_c1d05_row7_col2,#T_c1d05_row7_col3,#T_c1d05_row7_col4,#T_c1d05_row7_col5,#T_c1d05_row7_col6,#T_c1d05_row7_col7,#T_c1d05_row8_col0,#T_c1d05_row8_col1,#T_c1d05_row8_col2,#T_c1d05_row8_col3,#T_c1d05_row8_col4,#T_c1d05_row8_col5,#T_c1d05_row8_col6,#T_c1d05_row8_col7,#T_c1d05_row9_col0,#T_c1d05_row9_col1,#T_c1d05_row9_col2,#T_c1d05_row9_col3,#T_c1d05_row9_col4,#T_c1d05_row9_col5,#T_c1d05_row9_col6,#T_c1d05_row9_col7,#T_c1d05_row10_col0,#T_c1d05_row10_col1,#T_c1d05_row10_col2,#T_c1d05_row10_col4,#T_c1d05_row10_col5,#T_c1d05_row10_col6,#T_c1d05_row10_col7,#T_c1d05_row11_col0,#T_c1d05_row11_col1,#T_c1d05_row11_col2,#T_c1d05_row11_col3,#T_c1d05_row11_col5,#T_c1d05_row11_col6,#T_c1d05_row11_col7,#T_c1d05_row12_col0,#T_c1d05_row12_col1,#T_c1d05_row12_col2,#T_c1d05_row12_col3,#T_c1d05_row12_col4,#T_c1d05_row12_col5,#T_c1d05_row12_col6,#T_c1d05_row12_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_c1d05_row0_col1,#T_c1d05_row0_col5,#T_c1d05_row0_col6,#T_c1d05_row0_col7,#T_c1d05_row1_col1,#T_c1d05_row5_col2,#T_c1d05_row10_col3,#T_c1d05_row11_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_c1d05_row0_col8,#T_c1d05_row1_col8,#T_c1d05_row2_col8,#T_c1d05_row3_col8,#T_c1d05_row4_col8,#T_c1d05_row5_col8,#T_c1d05_row6_col8,#T_c1d05_row8_col8,#T_c1d05_row9_col8,#T_c1d05_row10_col8,#T_c1d05_row11_col8,#T_c1d05_row12_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_c1d05_row7_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_c1d05_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1d05_level0_row0" class="row_heading level0 row0" >et</th>
#                         <td id="T_c1d05_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_c1d05_row0_col1" class="data row0 col1" >0.9995</td>
#                         <td id="T_c1d05_row0_col2" class="data row0 col2" >0.9428</td>
#                         <td id="T_c1d05_row0_col3" class="data row0 col3" >0.7589</td>
#                         <td id="T_c1d05_row0_col4" class="data row0 col4" >0.9504</td>
#                         <td id="T_c1d05_row0_col5" class="data row0 col5" >0.8426</td>
#                         <td id="T_c1d05_row0_col6" class="data row0 col6" >0.8424</td>
#                         <td id="T_c1d05_row0_col7" class="data row0 col7" >0.8484</td>
#                         <td id="T_c1d05_row0_col8" class="data row0 col8" >3.7780</td>
#             </tr>
#             <tr>
#                         <th id="T_c1d05_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_c1d05_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_c1d05_row1_col1" class="data row1 col1" >0.9995</td>
#                         <td id="T_c1d05_row1_col2" class="data row1 col2" >0.9356</td>
#                         <td id="T_c1d05_row1_col3" class="data row1 col3" >0.7619</td>
#                         <td id="T_c1d05_row1_col4" class="data row1 col4" >0.9353</td>
#                         <td id="T_c1d05_row1_col5" class="data row1 col5" >0.8383</td>
#                         <td id="T_c1d05_row1_col6" class="data row1 col6" >0.8380</td>
#                         <td id="T_c1d05_row1_col7" class="data row1 col7" >0.8432</td>
#                         <td id="T_c1d05_row1_col8" class="data row1 col8" >14.4620</td>
#             </tr>
#             <tr>
#                         <th id="T_c1d05_level0_row2" class="row_heading level0 row2" >lda</th>
#                         <td id="T_c1d05_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#                         <td id="T_c1d05_row2_col1" class="data row2 col1" >0.9993</td>
#                         <td id="T_c1d05_row2_col2" class="data row2 col2" >0.8964</td>
#                         <td id="T_c1d05_row2_col3" class="data row2 col3" >0.7447</td>
#                         <td id="T_c1d05_row2_col4" class="data row2 col4" >0.8552</td>
#                         <td id="T_c1d05_row2_col5" class="data row2 col5" >0.7939</td>
#                         <td id="T_c1d05_row2_col6" class="data row2 col6" >0.7936</td>
#                         <td id="T_c1d05_row2_col7" class="data row2 col7" >0.7966</td>
#                         <td id="T_c1d05_row2_col8" class="data row2 col8" >0.4320</td>
#             </tr>
#             <tr>
#                         <th id="T_c1d05_level0_row3" class="row_heading level0 row3" >dt</th>
#                         <td id="T_c1d05_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#                         <td id="T_c1d05_row3_col1" class="data row3 col1" >0.9991</td>
#                         <td id="T_c1d05_row3_col2" class="data row3 col2" >0.8566</td>
#                         <td id="T_c1d05_row3_col3" class="data row3 col3" >0.7137</td>
#                         <td id="T_c1d05_row3_col4" class="data row3 col4" >0.7347</td>
#                         <td id="T_c1d05_row3_col5" class="data row3 col5" >0.7239</td>
#                         <td id="T_c1d05_row3_col6" class="data row3 col6" >0.7234</td>
#                         <td id="T_c1d05_row3_col7" class="data row3 col7" >0.7236</td>
#                         <td id="T_c1d05_row3_col8" class="data row3 col8" >2.9700</td>
#             </tr>
#             <tr>
#                         <th id="T_c1d05_level0_row4" class="row_heading level0 row4" >gbc</th>
#                         <td id="T_c1d05_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_c1d05_row4_col1" class="data row4 col1" >0.9991</td>
#                         <td id="T_c1d05_row4_col2" class="data row4 col2" >0.8150</td>
#                         <td id="T_c1d05_row4_col3" class="data row4 col3" >0.6568</td>
#                         <td id="T_c1d05_row4_col4" class="data row4 col4" >0.8038</td>
#                         <td id="T_c1d05_row4_col5" class="data row4 col5" >0.7169</td>
#                         <td id="T_c1d05_row4_col6" class="data row4 col6" >0.7165</td>
#                         <td id="T_c1d05_row4_col7" class="data row4 col7" >0.7231</td>
#                         <td id="T_c1d05_row4_col8" class="da

# %%
for model in best_models:
    print(model)
    print()
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=42, verbose=0,
#                      warm_start=False)
#
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)
#
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)
#
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')
#
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=42, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
etc = create_model("et", fold = 10)
rfc = create_model("rf", fold = 10)
lda = create_model("lda", fold = 10)
dtc = create_model("dt", fold = 10)
gbc = create_model("gbc", fold = 10)
# Out:
# <style  type="text/css" >
# #T_bafa7_row10_col0,#T_bafa7_row10_col1,#T_bafa7_row10_col2,#T_bafa7_row10_col3,#T_bafa7_row10_col4,#T_bafa7_row10_col5,#T_bafa7_row10_col6{
#             background:  yellow;
#         }</style><table id="T_bafa7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bafa7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bafa7_row0_col0" class="data row0 col0" >0.9984</td>
#                         <td id="T_bafa7_row0_col1" class="data row0 col1" >0.4714</td>
#                         <td id="T_bafa7_row0_col2" class="data row0 col2" >0.1714</td>
#                         <td id="T_bafa7_row0_col3" class="data row0 col3" >0.6000</td>
#                         <td id="T_bafa7_row0_col4" class="data row0 col4" >0.2667</td>
#                         <td id="T_bafa7_row0_col5" class="data row0 col5" >0.2661</td>
#                         <td id="T_bafa7_row0_col6" class="data row0 col6" >0.3202</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bafa7_row1_col0" class="data row1 col0" >0.9994</td>
#                         <td id="T_bafa7_row1_col1" class="data row1 col1" >0.8969</td>
#                         <td id="T_bafa7_row1_col2" class="data row1 col2" >0.7143</td>
#                         <td id="T_bafa7_row1_col3" class="data row1 col3" >0.8929</td>
#                         <td id="T_bafa7_row1_col4" class="data row1 col4" >0.7937</td>
#                         <td id="T_bafa7_row1_col5" class="data row1 col5" >0.7933</td>
#                         <td id="T_bafa7_row1_col6" class="data row1 col6" >0.7983</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_bafa7_row2_col0" class="data row2 col0" >0.9988</td>
#                         <td id="T_bafa7_row2_col1" class="data row2 col1" >0.8425</td>
#                         <td id="T_bafa7_row2_col2" class="data row2 col2" >0.6286</td>
#                         <td id="T_bafa7_row2_col3" class="data row2 col3" >0.6471</td>
#                         <td id="T_bafa7_row2_col4" class="data row2 col4" >0.6377</td>
#                         <td id="T_bafa7_row2_col5" class="data row2 col5" >0.6371</td>
#                         <td id="T_bafa7_row2_col6" class="data row2 col6" >0.6371</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_bafa7_row3_col0" class="data row3 col0" >0.9987</td>
#                         <td id="T_bafa7_row3_col1" class="data row3 col1" >0.5285</td>
#                         <td id="T_bafa7_row3_col2" class="data row3 col2" >0.3143</td>
#                         <td id="T_bafa7_row3_col3" class="data row3 col3" >0.7857</td>
#                         <td id="T_bafa7_row3_col4" class="data row3 col4" >0.4490</td>
#                         <td id="T_bafa7_row3_col5" class="data row3 col5" >0.4484</td>
#                         <td id="T_bafa7_row3_col6" class="data row3 col6" >0.4964</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_bafa7_row4_col0" class="data row4 col0" >0.9991</td>
#                         <td id="T_bafa7_row4_col1" class="data row4 col1" >0.6286</td>
#                         <td id="T_bafa7_row4_col2" class="data row4 col2" >0.5143</td>
#                         <td id="T_bafa7_row4_col3" class="data row4 col3" >0.9474</td>
#                         <td id="T_bafa7_row4_col4" class="data row4 col4" >0.6667</td>
#                         <td id="T_bafa7_row4_col5" class="data row4 col5" >0.6663</td>
#                         <td id="T_bafa7_row4_col6" class="data row4 col6" >0.6977</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_bafa7_row5_col0" class="data row5 col0" >0.9993</td>
#                         <td id="T_bafa7_row5_col1" class="data row5 col1" >0.8141</td>
#                         <td id="T_bafa7_row5_col2" class="data row5 col2" >0.6286</td>
#                         <td id="T_bafa7_row5_col3" class="data row5 col3" >0.9565</td>
#                         <td id="T_bafa7_row5_col4" class="data row5 col4" >0.7586</td>
#                         <td id="T_bafa7_row5_col5" class="data row5 col5" >0.7583</td>
#                         <td id="T_bafa7_row5_col6" class="data row5 col6" >0.7751</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_bafa7_row6_col0" class="data row6 col0" >0.9996</td>
#                         <td id="T_bafa7_row6_col1" class="data row6 col1" >0.8415</td>
#                         <td id="T_bafa7_row6_col2" class="data row6 col2" >0.7429</td>
#                         <td id="T_bafa7_row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_bafa7_row6_col4" class="data row6 col4" >0.8525</td>
#                         <td id="T_bafa7_row6_col5" class="data row6 col5" >0.8522</td>
#                         <td id="T_bafa7_row6_col6" class="data row6 col6" >0.8617</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_bafa7_row7_col0" class="data row7 col0" >0.9990</td>
#                         <td id="T_bafa7_row7_col1" class="data row7 col1" >0.6914</td>
#                         <td id="T_bafa7_row7_col2" class="data row7 col2" >0.5833</td>
#                         <td id="T_bafa7_row7_col3" class="data row7 col3" >0.7778</td>
#                         <td id="T_bafa7_row7_col4" class="data row7 col4" >0.6667</td>
#                         <td id="T_bafa7_row7_col5" class="data row7 col5" >0.6662</td>
#                         <td id="T_bafa7_row7_col6" class="data row7 col6" >0.6731</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_bafa7_row8_col0" class="data row8 col0" >0.9991</td>
#                         <td id="T_bafa7_row8_col1" class="data row8 col1" >0.7637</td>
#                         <td id="T_bafa7_row8_col2" class="data row8 col2" >0.6667</td>
#                         <td id="T_bafa7_row8_col3" class="data row8 col3" >0.8000</td>
#                         <td id="T_bafa7_row8_col4" class="data row8 col4" >0.7273</td>
#                         <td id="T_bafa7_row8_col5" class="data row8 col5" >0.7268</td>
#                         <td id="T_bafa7_row8_col6" class="data row8 col6" >0.7299</td>
#             </tr>
#             <tr>
#                         <th id="T_bafa7_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_bafa7_row9_col0" class="data row9 col0" >0.9991</td>
#                         <td id="T_bafa7_row9_col1" class="data row9 col1" >0.7058</td>
#                         <td id="T_bafa7_row9_col2" class="data row9 col2" >0.5833</td>
#                         <td id="T_bafa7_row9_col3" class="data row9 col3" >0.8750</td>
#                         <td id="T_bafa7_row9_col4" class="data row9 col4" >0.7000</td>
#                         <td id="T_bafa7_row9_col5" class="data row9 col5" >0.6996</td>
#                         <td id=

# %%
rfc_param_grid = {
    'bootstrap': [True],
    'max_depth': [80, 90, 100, 110],
    'max_features': [2, 3],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [8, 10, 12],
    'n_estimators': [100, 200, 300, 1000]
}

tuned_rfc = tune_model(rfc, custom_grid = rfc_param_grid)
# Out:
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   15:42:14
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .   Random Forest Classifier
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
