# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\Manav Doshi\Documents\LS 2021 Assignments\Fundamentals of MLOps\mlops_assignment\data\creditcard.csv', nrows = 28000)
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 27995  34804  0.905340 -0.444087 -0.335214  1.097341  0.347810  0.956708
# 27996  34804 -0.272894  1.182035 -0.378801  0.949242 -0.020458 -0.845142
# 27997  34804  1.204991  0.253059  0.251176  1.076599 -0.170065 -0.522115
# 27998  34805 -0.667309  0.521356  0.965784 -0.714486  0.967801 -0.779216
# 27999  34806  1.136767  0.115133  0.278527  1.205758  0.042336  0.327770
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 0      0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1     -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2      0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3      0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4      0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...         ...       ...       ...  ...       ...       ...       ...
# 27995  0.104177  0.214844  0.210624  ... -0.049647 -0.335160 -0.376953
# 27996  0.955518  0.148454 -0.719269  ...  0.204533  0.534778  0.226534
# 27997  0.070319 -0.037871  0.129104  ...  0.042323  0.161314 -0.055432
# 27998  0.869049 -0.166149 -0.725733  ... -0.378990 -1.322014 -0.001380
# 27999 -0.055043  0.167647  0.095019  ... -0.072368 -0.029223 -0.115358
#
#             V24       V25       V26       V27       V28  Amount  Class
# 0      0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1     -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2     -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3     -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4      0.141267 -0.206010  0.502292  0.219422  0.215153   69.99      0
# ...         ...       ...       ...       ...       ...     ...    ...
# 27995 -1.344595  0.731523 -0.260203 -0.000636  0.018537  169.67      0
# 27996  0.032599 -0.600684 -0.393867  0.284535  0.171296   89.99      0
# 27997  0.059273  0.582111 -0.295154  0.024198  0.014418    2.00      0
# 27998 -0.598644 -0.114377  0.660993 -0.043222  0.086252   30.99      0
# 27999 -0.294777  0.666087 -0.309418  0.033039  0.002663   12.55      0
#
# [28000 rows x 31 columns]

# %%
test_dataset = df.sample(frac = 0.1, random_state = 42)
df = df.drop(test_dataset.index)

df.reset_index(drop = True, inplace = True)
test_dataset.reset_index(drop = True, inplace = True)

print('Data for Model Training & Validation: ' + str(df.shape))
print('Unseen Data For Predictions: ' + str(test_dataset.shape))
# Out:
# Data for Model Training & Validation: (25200, 31)
# Unseen Data For Predictions: (2800, 31)

# %%
test_dataset.to_csv(r'C:\Users\Manav Doshi\Documents\LS 2021 Assignments\Fundamentals of MLOps\mlops_assignment\data\test.csv', index = False)

# %%
from pycaret.classification import *
import mlflow 
mlflow.set_tracking_uri('file:/C:\\Users\Manav Doshi\Documents\LS 2021 Assignments\Fundamentals of MLOps\mlops_assignment')

# %%
expt_basic = setup(
    data = df, 
    target = 'Class', 
    session_id=42,                      # Random seed to ensure reproducibility of the experiment with the same data
    train_size=0.8,                     # 80% training data & 20% held-out validation data
    numeric_imputation="median",        # "mean" by default
    categorical_imputation="mode",      # "constant" (not_available) by default
    log_experiment = True,
    experiment_name = 'Credit Card Fraud - Expt 2',
    log_plots = True,
)
# Out:
# <style  type="text/css" >
# #T_3ab67_row19_col1,#T_3ab67_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_3ab67_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ab67_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3ab67_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_3ab67_row0_col1" class="data row0 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3ab67_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_3ab67_row1_col1" class="data row1 col1" >Class</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3ab67_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_3ab67_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3ab67_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_3ab67_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3ab67_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_3ab67_row4_col1" class="data row4 col1" >(25200, 31)</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3ab67_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_3ab67_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3ab67_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_3ab67_row6_col1" class="data row6 col1" >30</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3ab67_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_3ab67_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3ab67_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_3ab67_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3ab67_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_3ab67_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_3ab67_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_3ab67_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_3ab67_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_3ab67_row11_col1" class="data row11 col1" >(20160, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_3ab67_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_3ab67_row12_col1" class="data row12 col1" >(5040, 30)</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_3ab67_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_3ab67_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_3ab67_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_3ab67_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_3ab67_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_3ab67_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_3ab67_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_3ab67_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_3ab67_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_3ab67_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_3ab67_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_3ab67_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_3ab67_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_3ab67_row19_col1" class="data row19 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_3ab67_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_3ab67_row20_col1" class="data row20 col1" >Credit Card Fraud - Expt 2</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_3ab67_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_3ab67_row21_col1" class="data row21 col1" >35c5</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_3ab67_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_3ab67_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_3ab67_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_3ab67_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3ab67_level0_row24" class="
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# <ipython-input-6-2a272e671462> in <module>
# ----> 1 expt_basic = setup(
#       2     data = df,
#       3     target = 'Class',
#       4     session_id=42,                      # Random seed to ensure reproducibility of the experiment with the same data
#       5     train_size=0.8,                     # 80% training data & 20% held-out validation data
#
# ~\AppData\Roaming\Python\Python38\site-packages\pycaret\classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     579         log_plots = ["auc", "confusion_matrix", "feature"]
#     580
# --> 581     return pycaret.internal.tabular.setup(
#     582         ml_usecase="classification",
#     583         available_plots=available_plots,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pycaret\internal\tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1706
#    1707         # mlflow logging
# -> 1708         mlflow.set_experiment(exp_name_log)
#    1709
#    1710         run_name_ = f"Session Initialized {USI}"
#
# ~\AppData\Roaming\Python\Python38\site-packages\mlflow\tracking\fluent.py in set_experiment(experiment_name)
#      82     """
#      83     client = MlflowClient()
# ---> 84     experiment = client.get_experiment_by_name(experiment_name)
#      85     exp_id = experiment.experiment_id if experiment else None
#      86     if exp_id is None:  # id can be 0
#
# ~\AppData\Roaming\Python\Python38\site-packages\mlflow\tracking\client.py in get_experiment_by_name(self, name)
#     461             Lifecycle_stage: active
#     462         """
# --> 463         return self._tracking_client.get_experiment_by_name(name)
#     464
#     465     def create_experiment(self, name: str, artifact_location: Optional[str] = None) -> str:
#
# ~\AppData\Roaming\Python\Python38\site-packages\mlflow\tracking\_tracking_service\client.py in get_experiment_by_name(self, name)
#     153         :return: :py:class:`mlflow.entities.Experiment`
#     154         """
# --> 155         return self.store.get_experiment_by_name(name)
#     156
#     157     def create_experiment(self, name, artifact_location=None):
#
# ~\AppData\Roaming\Python\Python38\site-packages\mlflow\store\tracking\abstract_store.py in get_experiment_by_name(self, experiment_name)
#      74         :return: A single :py:class:`mlflow.entities.Experiment` object if it exists.
#      75         """
# ---> 76         for experiment in self.list_experiments(ViewType.ALL):
#      77             if experiment.name == experiment_name:
#      78                 return experiment
#
# ~\AppData\Roaming\Python\Python38\site-packages\mlflow\store\tracking\file_store.py in list_experiments(self, view_type, max_results, page_token)
#     254             try:
#     255                 # trap and warn known issues, will raise unexpected exceptions to caller
# --> 256                 experiment = self._get_experiment(exp_id, view_type)
#     257                 if experiment:
#     258                     experiments.append(experiment)
#
# ~\AppData\Roaming\Python\Python38\site-packages\mlflow\store\tracking\file_store.py in _get_experiment(self, experiment_id, view_type)
#     327     def _get_experiment(self, experiment_id, view_type=ViewType.ALL):
#     328         self._check_root_dir()
# --> 329         _validate_experiment_id(experiment_id)
#     330         experiment_dir = self._get_experiment_path(experiment_id, view_type)
#     331         if experiment_dir is None:
#
# ~\AppData\Roaming\Python\Python38\site-packages\mlflow\utils\validation.py in _validate_experiment_id(exp_id)
#     219     """Check that `experiment_id`is a valid string or None, raise an exception if it isn't."""
#     220     if exp_id is not None and _EXPERIMENT_ID_REGEX.match(exp_id) is None:
# --> 221         raise MlflowException(
#     222             "Invalid experiment ID: '%s'" % exp_id, error_code=INVALID_PARAMETER_VALUE
#     223         )
#
# MlflowException: Invalid experiment ID: '.dvc'

# %%
best_models = compare_models(sort = "F1", n_select = 2)

# %%
for model in best_models:
    print(model)

# %%
etc = create_model('et', fold = 10)

# %%
lgbm = create_model('lightgbm', fold = 10)
# Out:
# <style  type="text/css" >
# #T_4801c_row10_col0,#T_4801c_row10_col1,#T_4801c_row10_col2,#T_4801c_row10_col3,#T_4801c_row10_col4,#T_4801c_row10_col5,#T_4801c_row10_col6{
#             background:  yellow;
#         }</style><table id="T_4801c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4801c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4801c_row0_col0" class="data row0 col0" >0.9995</td>
#                         <td id="T_4801c_row0_col1" class="data row0 col1" >0.8349</td>
#                         <td id="T_4801c_row0_col2" class="data row0 col2" >0.8333</td>
#                         <td id="T_4801c_row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_4801c_row0_col4" class="data row0 col4" >0.9091</td>
#                         <td id="T_4801c_row0_col5" class="data row0 col5" >0.9088</td>
#                         <td id="T_4801c_row0_col6" class="data row0 col6" >0.9126</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4801c_row1_col0" class="data row1 col0" >1.0000</td>
#                         <td id="T_4801c_row1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_4801c_row1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_4801c_row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_4801c_row1_col4" class="data row1 col4" >1.0000</td>
#                         <td id="T_4801c_row1_col5" class="data row1 col5" >1.0000</td>
#                         <td id="T_4801c_row1_col6" class="data row1 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4801c_row2_col0" class="data row2 col0" >1.0000</td>
#                         <td id="T_4801c_row2_col1" class="data row2 col1" >1.0000</td>
#                         <td id="T_4801c_row2_col2" class="data row2 col2" >1.0000</td>
#                         <td id="T_4801c_row2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_4801c_row2_col4" class="data row2 col4" >1.0000</td>
#                         <td id="T_4801c_row2_col5" class="data row2 col5" >1.0000</td>
#                         <td id="T_4801c_row2_col6" class="data row2 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4801c_row3_col0" class="data row3 col0" >0.9990</td>
#                         <td id="T_4801c_row3_col1" class="data row3 col1" >0.8574</td>
#                         <td id="T_4801c_row3_col2" class="data row3 col2" >0.7143</td>
#                         <td id="T_4801c_row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_4801c_row3_col4" class="data row3 col4" >0.8333</td>
#                         <td id="T_4801c_row3_col5" class="data row3 col5" >0.8328</td>
#                         <td id="T_4801c_row3_col6" class="data row3 col6" >0.8447</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4801c_row4_col0" class="data row4 col0" >1.0000</td>
#                         <td id="T_4801c_row4_col1" class="data row4 col1" >1.0000</td>
#                         <td id="T_4801c_row4_col2" class="data row4 col2" >1.0000</td>
#                         <td id="T_4801c_row4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_4801c_row4_col4" class="data row4 col4" >1.0000</td>
#                         <td id="T_4801c_row4_col5" class="data row4 col5" >1.0000</td>
#                         <td id="T_4801c_row4_col6" class="data row4 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4801c_row5_col0" class="data row5 col0" >0.9995</td>
#                         <td id="T_4801c_row5_col1" class="data row5 col1" >0.9998</td>
#                         <td id="T_4801c_row5_col2" class="data row5 col2" >1.0000</td>
#                         <td id="T_4801c_row5_col3" class="data row5 col3" >0.8750</td>
#                         <td id="T_4801c_row5_col4" class="data row5 col4" >0.9333</td>
#                         <td id="T_4801c_row5_col5" class="data row5 col5" >0.9331</td>
#                         <td id="T_4801c_row5_col6" class="data row5 col6" >0.9352</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4801c_row6_col0" class="data row6 col0" >0.9990</td>
#                         <td id="T_4801c_row6_col1" class="data row6 col1" >0.8658</td>
#                         <td id="T_4801c_row6_col2" class="data row6 col2" >0.7143</td>
#                         <td id="T_4801c_row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_4801c_row6_col4" class="data row6 col4" >0.8333</td>
#                         <td id="T_4801c_row6_col5" class="data row6 col5" >0.8328</td>
#                         <td id="T_4801c_row6_col6" class="data row6 col6" >0.8447</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4801c_row7_col0" class="data row7 col0" >0.9985</td>
#                         <td id="T_4801c_row7_col1" class="data row7 col1" >0.9964</td>
#                         <td id="T_4801c_row7_col2" class="data row7 col2" >0.7143</td>
#                         <td id="T_4801c_row7_col3" class="data row7 col3" >0.8333</td>
#                         <td id="T_4801c_row7_col4" class="data row7 col4" >0.7692</td>
#                         <td id="T_4801c_row7_col5" class="data row7 col5" >0.7685</td>
#                         <td id="T_4801c_row7_col6" class="data row7 col6" >0.7708</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4801c_row8_col0" class="data row8 col0" >0.9990</td>
#                         <td id="T_4801c_row8_col1" class="data row8 col1" >0.9999</td>
#                         <td id="T_4801c_row8_col2" class="data row8 col2" >0.8571</td>
#                         <td id="T_4801c_row8_col3" class="data row8 col3" >0.8571</td>
#                         <td id="T_4801c_row8_col4" class="data row8 col4" >0.8571</td>
#                         <td id="T_4801c_row8_col5" class="data row8 col5" >0.8566</td>
#                         <td id="T_4801c_row8_col6" class="data row8 col6" >0.8566</td>
#             </tr>
#             <tr>
#                         <th id="T_4801c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4801c_row9_col0" class="data row9 col0" >0.9995</td>
#                         <td id="T_4801c_row9_col1" class="data row9 col1" >0.9991</td>
#                         <td id="T_4801c_row9_col2" class="data row9 col2" >0.8571</td>
#                         <td id="T_4801c_row9_col3" class="data row9 col3" >1.0000</td>
#                         <td id="T_4801c_row9_col4" class="data row9 col4" >0.9231</td>
#                         <td id="T_4801c_row9_col5" class="data row9 col5" >0.9228</td>
#                         <td id=

# %%
tuned_etc = tune_model(etc)
# Out:
# <style  type="text/css" >
# #T_2e10c_row10_col0,#T_2e10c_row10_col1,#T_2e10c_row10_col2,#T_2e10c_row10_col3,#T_2e10c_row10_col4,#T_2e10c_row10_col5,#T_2e10c_row10_col6{
#             background:  yellow;
#         }</style><table id="T_2e10c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2e10c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2e10c_row0_col0" class="data row0 col0" >0.9980</td>
#                         <td id="T_2e10c_row0_col1" class="data row0 col1" >0.9988</td>
#                         <td id="T_2e10c_row0_col2" class="data row0 col2" >0.3333</td>
#                         <td id="T_2e10c_row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_2e10c_row0_col4" class="data row0 col4" >0.5000</td>
#                         <td id="T_2e10c_row0_col5" class="data row0 col5" >0.4993</td>
#                         <td id="T_2e10c_row0_col6" class="data row0 col6" >0.5768</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2e10c_row1_col0" class="data row1 col0" >0.9990</td>
#                         <td id="T_2e10c_row1_col1" class="data row1 col1" >0.9996</td>
#                         <td id="T_2e10c_row1_col2" class="data row1 col2" >0.7143</td>
#                         <td id="T_2e10c_row1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_2e10c_row1_col4" class="data row1 col4" >0.8333</td>
#                         <td id="T_2e10c_row1_col5" class="data row1 col5" >0.8328</td>
#                         <td id="T_2e10c_row1_col6" class="data row1 col6" >0.8447</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2e10c_row2_col0" class="data row2 col0" >0.9995</td>
#                         <td id="T_2e10c_row2_col1" class="data row2 col1" >0.9998</td>
#                         <td id="T_2e10c_row2_col2" class="data row2 col2" >0.8571</td>
#                         <td id="T_2e10c_row2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_2e10c_row2_col4" class="data row2 col4" >0.9231</td>
#                         <td id="T_2e10c_row2_col5" class="data row2 col5" >0.9228</td>
#                         <td id="T_2e10c_row2_col6" class="data row2 col6" >0.9256</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2e10c_row3_col0" class="data row3 col0" >0.9995</td>
#                         <td id="T_2e10c_row3_col1" class="data row3 col1" >0.9979</td>
#                         <td id="T_2e10c_row3_col2" class="data row3 col2" >0.8571</td>
#                         <td id="T_2e10c_row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_2e10c_row3_col4" class="data row3 col4" >0.9231</td>
#                         <td id="T_2e10c_row3_col5" class="data row3 col5" >0.9228</td>
#                         <td id="T_2e10c_row3_col6" class="data row3 col6" >0.9256</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2e10c_row4_col0" class="data row4 col0" >0.9990</td>
#                         <td id="T_2e10c_row4_col1" class="data row4 col1" >0.9999</td>
#                         <td id="T_2e10c_row4_col2" class="data row4 col2" >0.7143</td>
#                         <td id="T_2e10c_row4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_2e10c_row4_col4" class="data row4 col4" >0.8333</td>
#                         <td id="T_2e10c_row4_col5" class="data row4 col5" >0.8328</td>
#                         <td id="T_2e10c_row4_col6" class="data row4 col6" >0.8447</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2e10c_row5_col0" class="data row5 col0" >0.9975</td>
#                         <td id="T_2e10c_row5_col1" class="data row5 col1" >0.9993</td>
#                         <td id="T_2e10c_row5_col2" class="data row5 col2" >0.4286</td>
#                         <td id="T_2e10c_row5_col3" class="data row5 col3" >0.7500</td>
#                         <td id="T_2e10c_row5_col4" class="data row5 col4" >0.5455</td>
#                         <td id="T_2e10c_row5_col5" class="data row5 col5" >0.5443</td>
#                         <td id="T_2e10c_row5_col6" class="data row5 col6" >0.5659</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2e10c_row6_col0" class="data row6 col0" >0.9985</td>
#                         <td id="T_2e10c_row6_col1" class="data row6 col1" >0.9936</td>
#                         <td id="T_2e10c_row6_col2" class="data row6 col2" >0.7143</td>
#                         <td id="T_2e10c_row6_col3" class="data row6 col3" >0.8333</td>
#                         <td id="T_2e10c_row6_col4" class="data row6 col4" >0.7692</td>
#                         <td id="T_2e10c_row6_col5" class="data row6 col5" >0.7685</td>
#                         <td id="T_2e10c_row6_col6" class="data row6 col6" >0.7708</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2e10c_row7_col0" class="data row7 col0" >0.9985</td>
#                         <td id="T_2e10c_row7_col1" class="data row7 col1" >0.9670</td>
#                         <td id="T_2e10c_row7_col2" class="data row7 col2" >0.5714</td>
#                         <td id="T_2e10c_row7_col3" class="data row7 col3" >1.0000</td>
#                         <td id="T_2e10c_row7_col4" class="data row7 col4" >0.7273</td>
#                         <td id="T_2e10c_row7_col5" class="data row7 col5" >0.7266</td>
#                         <td id="T_2e10c_row7_col6" class="data row7 col6" >0.7554</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2e10c_row8_col0" class="data row8 col0" >0.9990</td>
#                         <td id="T_2e10c_row8_col1" class="data row8 col1" >0.9999</td>
#                         <td id="T_2e10c_row8_col2" class="data row8 col2" >0.7143</td>
#                         <td id="T_2e10c_row8_col3" class="data row8 col3" >1.0000</td>
#                         <td id="T_2e10c_row8_col4" class="data row8 col4" >0.8333</td>
#                         <td id="T_2e10c_row8_col5" class="data row8 col5" >0.8328</td>
#                         <td id="T_2e10c_row8_col6" class="data row8 col6" >0.8447</td>
#             </tr>
#             <tr>
#                         <th id="T_2e10c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2e10c_row9_col0" class="data row9 col0" >0.9990</td>
#                         <td id="T_2e10c_row9_col1" class="data row9 col1" >0.9996</td>
#                         <td id="T_2e10c_row9_col2" class="data row9 col2" >0.7143</td>
#                         <td id="T_2e10c_row9_col3" class="data row9 col3" >1.0000</td>
#                         <td id="T_2e10c_row9_col4" class="data row9 col4" >0.8333</td>
#                         <td id="T_2e10c_row9_col5" class="data row9 col5" >0.8328</td>
#                         <td id=

# %%
tuned_lgbm = tune_model(lgbm)
# Out:
# <style  type="text/css" >
# #T_acaf6_row10_col0,#T_acaf6_row10_col1,#T_acaf6_row10_col2,#T_acaf6_row10_col3,#T_acaf6_row10_col4,#T_acaf6_row10_col5,#T_acaf6_row10_col6{
#             background:  yellow;
#         }</style><table id="T_acaf6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_acaf6_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_acaf6_row0_col0" class="data row0 col0" >0.9995</td>
#                         <td id="T_acaf6_row0_col1" class="data row0 col1" >0.9998</td>
#                         <td id="T_acaf6_row0_col2" class="data row0 col2" >0.8333</td>
#                         <td id="T_acaf6_row0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_acaf6_row0_col4" class="data row0 col4" >0.9091</td>
#                         <td id="T_acaf6_row0_col5" class="data row0 col5" >0.9088</td>
#                         <td id="T_acaf6_row0_col6" class="data row0 col6" >0.9126</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_acaf6_row1_col0" class="data row1 col0" >0.9995</td>
#                         <td id="T_acaf6_row1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_acaf6_row1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_acaf6_row1_col3" class="data row1 col3" >0.8750</td>
#                         <td id="T_acaf6_row1_col4" class="data row1 col4" >0.9333</td>
#                         <td id="T_acaf6_row1_col5" class="data row1 col5" >0.9331</td>
#                         <td id="T_acaf6_row1_col6" class="data row1 col6" >0.9352</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_acaf6_row2_col0" class="data row2 col0" >0.9995</td>
#                         <td id="T_acaf6_row2_col1" class="data row2 col1" >1.0000</td>
#                         <td id="T_acaf6_row2_col2" class="data row2 col2" >0.8571</td>
#                         <td id="T_acaf6_row2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_acaf6_row2_col4" class="data row2 col4" >0.9231</td>
#                         <td id="T_acaf6_row2_col5" class="data row2 col5" >0.9228</td>
#                         <td id="T_acaf6_row2_col6" class="data row2 col6" >0.9256</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_acaf6_row3_col0" class="data row3 col0" >0.9995</td>
#                         <td id="T_acaf6_row3_col1" class="data row3 col1" >0.9997</td>
#                         <td id="T_acaf6_row3_col2" class="data row3 col2" >0.8571</td>
#                         <td id="T_acaf6_row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_acaf6_row3_col4" class="data row3 col4" >0.9231</td>
#                         <td id="T_acaf6_row3_col5" class="data row3 col5" >0.9228</td>
#                         <td id="T_acaf6_row3_col6" class="data row3 col6" >0.9256</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_acaf6_row4_col0" class="data row4 col0" >1.0000</td>
#                         <td id="T_acaf6_row4_col1" class="data row4 col1" >1.0000</td>
#                         <td id="T_acaf6_row4_col2" class="data row4 col2" >1.0000</td>
#                         <td id="T_acaf6_row4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_acaf6_row4_col4" class="data row4 col4" >1.0000</td>
#                         <td id="T_acaf6_row4_col5" class="data row4 col5" >1.0000</td>
#                         <td id="T_acaf6_row4_col6" class="data row4 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_acaf6_row5_col0" class="data row5 col0" >0.9990</td>
#                         <td id="T_acaf6_row5_col1" class="data row5 col1" >0.9996</td>
#                         <td id="T_acaf6_row5_col2" class="data row5 col2" >0.8571</td>
#                         <td id="T_acaf6_row5_col3" class="data row5 col3" >0.8571</td>
#                         <td id="T_acaf6_row5_col4" class="data row5 col4" >0.8571</td>
#                         <td id="T_acaf6_row5_col5" class="data row5 col5" >0.8566</td>
#                         <td id="T_acaf6_row5_col6" class="data row5 col6" >0.8566</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_acaf6_row6_col0" class="data row6 col0" >0.9995</td>
#                         <td id="T_acaf6_row6_col1" class="data row6 col1" >0.9925</td>
#                         <td id="T_acaf6_row6_col2" class="data row6 col2" >0.8571</td>
#                         <td id="T_acaf6_row6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_acaf6_row6_col4" class="data row6 col4" >0.9231</td>
#                         <td id="T_acaf6_row6_col5" class="data row6 col5" >0.9228</td>
#                         <td id="T_acaf6_row6_col6" class="data row6 col6" >0.9256</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_acaf6_row7_col0" class="data row7 col0" >0.9980</td>
#                         <td id="T_acaf6_row7_col1" class="data row7 col1" >0.9958</td>
#                         <td id="T_acaf6_row7_col2" class="data row7 col2" >0.5714</td>
#                         <td id="T_acaf6_row7_col3" class="data row7 col3" >0.8000</td>
#                         <td id="T_acaf6_row7_col4" class="data row7 col4" >0.6667</td>
#                         <td id="T_acaf6_row7_col5" class="data row7 col5" >0.6657</td>
#                         <td id="T_acaf6_row7_col6" class="data row7 col6" >0.6752</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_acaf6_row8_col0" class="data row8 col0" >0.9995</td>
#                         <td id="T_acaf6_row8_col1" class="data row8 col1" >0.9999</td>
#                         <td id="T_acaf6_row8_col2" class="data row8 col2" >1.0000</td>
#                         <td id="T_acaf6_row8_col3" class="data row8 col3" >0.8750</td>
#                         <td id="T_acaf6_row8_col4" class="data row8 col4" >0.9333</td>
#                         <td id="T_acaf6_row8_col5" class="data row8 col5" >0.9331</td>
#                         <td id="T_acaf6_row8_col6" class="data row8 col6" >0.9352</td>
#             </tr>
#             <tr>
#                         <th id="T_acaf6_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_acaf6_row9_col0" class="data row9 col0" >0.9990</td>
#                         <td id="T_acaf6_row9_col1" class="data row9 col1" >0.9967</td>
#                         <td id="T_acaf6_row9_col2" class="data row9 col2" >0.7143</td>
#                         <td id="T_acaf6_row9_col3" class="data row9 col3" >1.0000</td>
#                         <td id="T_acaf6_row9_col4" class="data row9 col4" >0.8333</td>
#                         <td id="T_acaf6_row9_col5" class="data row9 col5" >0.8328</td>
#                         <td id=

# %%
plot_model(tuned_etc, plot = 'confusion_matrix')

# %%
plot_model(tuned_etc, plot = 'pr')

# %%
plot_model(tuned_lgbm, plot = 'confusion_matrix')

# %%
plot_model(tuned_lgbm, plot = 'pr')

# %%
predict_model(tuned_etc)
# Out:
# <style  type="text/css" >
# </style><table id="T_6bc27_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6bc27_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6bc27_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_6bc27_row0_col1" class="data row0 col1" >0.9992</td>
#                         <td id="T_6bc27_row0_col2" class="data row0 col2" >0.9870</td>
#                         <td id="T_6bc27_row0_col3" class="data row0 col3" >0.7143</td>
#                         <td id="T_6bc27_row0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_6bc27_row0_col5" class="data row0 col5" >0.8333</td>
#                         <td id="T_6bc27_row0_col6" class="data row0 col6" >0.8329</td>
#                         <td id="T_6bc27_row0_col7" class="data row0 col7" >0.8448</td>
#             </tr>
#     </tbody></table>
#          Time        V1        V2        V3        V4        V5        V6  \
# 0       251.0  1.071813 -0.249927  0.189825  0.191109 -0.615779 -1.074104
# 1     33901.0 -1.507007  1.631328  0.926689  1.223915 -0.466279  0.201020
# 2      7399.0 -1.411520  1.856636  1.486158  1.336563 -0.771817 -0.659310
# 3     25808.0 -0.897475  0.963371  0.997351  0.329928  0.998766 -1.287190
# 4     31714.0  1.380775 -0.356583  0.387365  0.256580 -0.419997  0.439780
# ...       ...       ...       ...       ...       ...       ...       ...
# 5035   4927.0 -0.777469  1.101204  1.077597 -1.130260  0.012039 -0.395883
# 5036  34772.0  1.304326 -0.847171  1.099974 -0.550016 -1.472769  0.140762
# 5037  28222.0 -0.645705  0.832049  2.789388  1.906653 -0.273674  0.154352
# 5038  11816.0 -0.765095  0.562795 -0.885347 -2.588230  1.988829  2.963951
# 5039  26427.0  1.364086 -0.805040  0.647718 -0.921913 -1.110406  0.053914
#
#             V7        V8        V9  ...       V23       V24       V25  \
# 0     0.213633 -0.322513  0.046084  ... -0.159514  0.487009  0.365901
# 1     0.507577  0.386769 -0.151936  ... -0.184727  0.103040  0.225850
# 2    -0.010448  0.406383  1.052674  ...  0.054478  0.870111 -0.206559
# 3     0.713085  0.019353 -0.859152  ... -0.234309  0.381128  0.193193
# 4    -0.642288 -0.045559 -0.604107  ... -0.252241 -0.978038  0.766570
# ...        ...       ...       ...  ...       ...       ...       ...
# 5035  0.153629  0.376384  0.610353  ... -0.004438  0.023481 -0.358635
# 5036 -1.209611  0.204178 -0.267786  ...  0.090533  0.038795  0.020292
# 5037  0.110742 -0.086928 -0.414622  ... -0.166374  0.407840 -0.205901
# 5038 -0.400776  1.071862 -0.366301  ... -0.004510  0.953658 -0.278727
# 5039 -1.159625  0.157693 -0.530408  ... -0.223120 -0.466099  0.486287
#
#            V26       V27       V28      Amount  Class  Label   Score
# 0     1.056073 -0.101425  0.022797  120.000000      0      0  0.9997
# 1    -0.203852  0.002925  0.175837   66.089996      0      0  0.9998
# 2    -0.608570 -0.428243 -0.160268    1.440000      0      0  0.9998
# 3    -0.511092  0.092647  0.150261    1.000000      0      0  0.9978
# 4    -0.142444  0.085791  0.025083   16.559999      0      0  0.9998
# ...        ...       ...       ...         ...    ...    ...     ...
# 5035  0.709017 -0.328041 -0.056190    0.770000      0      0  0.9998
# 5036  0.962899 -0.010031  0.008369    7.990000      0      0  0.9998
# 5037  0.017461 -0.342282 -0.161598   19.360001      0      0  0.9993
# 5038  0.773703  0.009935  0.116981   12.500000      0      0  0.9996
# 5039 -0.015086  0.027143  0.008510   24.990000      0      0  0.9998
#
# [5040 rows x 33 columns]

# %%
predict_model(tuned_lgbm)
# Out:
# <style  type="text/css" >
# </style><table id="T_a98bd_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a98bd_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a98bd_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_a98bd_row0_col1" class="data row0 col1" >0.9998</td>
#                         <td id="T_a98bd_row0_col2" class="data row0 col2" >0.9843</td>
#                         <td id="T_a98bd_row0_col3" class="data row0 col3" >0.9286</td>
#                         <td id="T_a98bd_row0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_a98bd_row0_col5" class="data row0 col5" >0.9630</td>
#                         <td id="T_a98bd_row0_col6" class="data row0 col6" >0.9629</td>
#                         <td id="T_a98bd_row0_col7" class="data row0 col7" >0.9635</td>
#             </tr>
#     </tbody></table>
#          Time        V1        V2        V3        V4        V5        V6  \
# 0       251.0  1.071813 -0.249927  0.189825  0.191109 -0.615779 -1.074104
# 1     33901.0 -1.507007  1.631328  0.926689  1.223915 -0.466279  0.201020
# 2      7399.0 -1.411520  1.856636  1.486158  1.336563 -0.771817 -0.659310
# 3     25808.0 -0.897475  0.963371  0.997351  0.329928  0.998766 -1.287190
# 4     31714.0  1.380775 -0.356583  0.387365  0.256580 -0.419997  0.439780
# ...       ...       ...       ...       ...       ...       ...       ...
# 5035   4927.0 -0.777469  1.101204  1.077597 -1.130260  0.012039 -0.395883
# 5036  34772.0  1.304326 -0.847171  1.099974 -0.550016 -1.472769  0.140762
# 5037  28222.0 -0.645705  0.832049  2.789388  1.906653 -0.273674  0.154352
# 5038  11816.0 -0.765095  0.562795 -0.885347 -2.588230  1.988829  2.963951
# 5039  26427.0  1.364086 -0.805040  0.647718 -0.921913 -1.110406  0.053914
#
#             V7        V8        V9  ...       V23       V24       V25  \
# 0     0.213633 -0.322513  0.046084  ... -0.159514  0.487009  0.365901
# 1     0.507577  0.386769 -0.151936  ... -0.184727  0.103040  0.225850
# 2    -0.010448  0.406383  1.052674  ...  0.054478  0.870111 -0.206559
# 3     0.713085  0.019353 -0.859152  ... -0.234309  0.381128  0.193193
# 4    -0.642288 -0.045559 -0.604107  ... -0.252241 -0.978038  0.766570
# ...        ...       ...       ...  ...       ...       ...       ...
# 5035  0.153629  0.376384  0.610353  ... -0.004438  0.023481 -0.358635
# 5036 -1.209611  0.204178 -0.267786  ...  0.090533  0.038795  0.020292
# 5037  0.110742 -0.086928 -0.414622  ... -0.166374  0.407840 -0.205901
# 5038 -0.400776  1.071862 -0.366301  ... -0.004510  0.953658 -0.278727
# 5039 -1.159625  0.157693 -0.530408  ... -0.223120 -0.466099  0.486287
#
#            V26       V27       V28      Amount  Class  Label   Score
# 0     1.056073 -0.101425  0.022797  120.000000      0      0  0.9999
# 1    -0.203852  0.002925  0.175837   66.089996      0      0  1.0000
# 2    -0.608570 -0.428243 -0.160268    1.440000      0      0  1.0000
# 3    -0.511092  0.092647  0.150261    1.000000      0      0  1.0000
# 4    -0.142444  0.085791  0.025083   16.559999      0      0  0.9999
# ...        ...       ...       ...         ...    ...    ...     ...
# 5035  0.709017 -0.328041 -0.056190    0.770000      0      0  1.0000
# 5036  0.962899 -0.010031  0.008369    7.990000      0      0  0.9998
# 5037  0.017461 -0.342282 -0.161598   19.360001      0      0  0.9999
# 5038  0.773703  0.009935  0.116981   12.500000      0      0  1.0000
# 5039 -0.015086  0.027143  0.008510   24.990000      0      0  1.0000
#
# [5040 rows x 33 columns]

# %%
final_etc = finalize_model(tuned_etc)

# %%
final_lgbm = finalize_model(tuned_lgbm)

# %%
deploy_model(model = final_etc, model_name = 'etc_deployed', platform = 'aws', authentication = {'bucket' : 'mlops200100094'})
# Out:
# Model Successfully Deployed on AWS S3

# %%
deploy_model(model = final_lgbm, model_name = 'lgbm_deployed', platform = 'aws', authentication = {'bucket' : 'mlops200100094'})
# Out:
# Model Successfully Deployed on AWS S3
